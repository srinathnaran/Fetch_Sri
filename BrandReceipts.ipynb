# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv('/Users/srinathnarayanan/Downloads/Fetch Rewards/users.csv')

# %%
df
# Out:
#                     _id__$oid  active  createdDate__$date  lastLogin__$date  \
# 0    5ff1e194b6a9d73a3a9f1052    True       1609687444800      1.609688e+12
# 1    5ff1e194b6a9d73a3a9f1052    True       1609687444800      1.609688e+12
# 2    5ff1e194b6a9d73a3a9f1052    True       1609687444800      1.609688e+12
# 3    5ff1e1eacfcf6c399c274ae6    True       1609687530554      1.609688e+12
# 4    5ff1e194b6a9d73a3a9f1052    True       1609687444800      1.609688e+12
# ..                        ...     ...                 ...               ...
# 490  54943462e4b07e684157a532    True       1418998882381      1.614963e+12
# 491  54943462e4b07e684157a532    True       1418998882381      1.614963e+12
# 492  54943462e4b07e684157a532    True       1418998882381      1.614963e+12
# 493  54943462e4b07e684157a532    True       1418998882381      1.614963e+12
# 494  54943462e4b07e684157a532    True       1418998882381      1.614963e+12
#
#             role signUpSource state
# ...

# %%
df = df.rename(columns={"_id__$oid": "User_id"})
df = df.rename(columns={"createdDate__$date":"CreateDateUser"})
df = df.rename(columns={"lastLogin__$date":"lastLoginDate"})

# %%
df['CreateDateUser']=df['CreateDateUser'].apply(lambda d: datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

# %%
df.fillna(0)
df.replace(np.nan, 0)
# Out:
#                       User_id  active       CreateDateUser  lastLoginDate  \
# 0    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 1    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 2    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 3    5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30   1.609688e+12
# 4    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# ..                        ...     ...                  ...            ...
# 490  54943462e4b07e684157a532    True  2014-12-19 09:21:22   1.614963e+12
# 491  54943462e4b07e684157a532    True  2014-12-19 09:21:22   1.614963e+12
# 492  54943462e4b07e684157a532    True  2014-12-19 09:21:22   1.614963e+12
# 493  54943462e4b07e684157a532    True  2014-12-19 09:21:22   1.614963e+12
# 494  54943462e4b07e684157a532    True  2014-12-19 09:21:22   1.614963e+12
#
#             role signUpSource state
# 0       consumer        Email    WI
# ...

# %%
df['monthUser'] = pd.DatetimeIndex(df['CreateDateUser']).month
df['yearUser'] = pd.DatetimeIndex(df['CreateDateUser']).year
df.head()
# Out:
#                     User_id  active       CreateDateUser  lastLoginDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 3  5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30   1.609688e+12
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
#
#        role signUpSource state  monthUser  yearUser
# 0  consumer        Email    WI          1      2021
# 1  consumer        Email    WI          1      2021
# 2  consumer        Email    WI          1      2021
# 3  consumer        Email    WI          1      2021
# 4  consumer        Email    WI          1      2021

# %%
df.to_csv( r'/Users/srinathnarayanan/Downloads/Fetch/Users.csv', header=True, index=False)

# %%
df1 = pd.read_csv('/Users/srinathnarayanan/Downloads/Fetch Rewards/Brands.csv')

# %%
df1
# Out:
#                      _id__$oid       barcode            category  \
# 0     601ac115be37ce2ead437551  511111019862              Baking
# 1     601c5460be37ce2ead43755f  511111519928           Beverages
# 2     601ac142be37ce2ead43755d  511111819905              Baking
# 3     601ac142be37ce2ead43755a  511111519874              Baking
# 4     601ac142be37ce2ead43755e  511111319917      Candy & Sweets
# ...                        ...           ...                 ...
# 1162  5f77274dbe37ce6b592e90c0  511111116752              Baking
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328  Breakfast & Cereal
# 1164  5f494c6e04db711dd8fe87e7  511111416173      Candy & Sweets
# 1165  5a021611e4b00efe02b02a57  511111400608             Grocery
# 1166  6026d757be37ce6369301468  511111019930              Baking
#
#           categoryCode            cpg__$id__$oid cpg__$ref  \
# 0               BAKING  601ac114be37ce2ead437550      Cogs
# 1            BEVERAGES  5332f5fbe4b03c9a25efd0ba      Cogs
# ...

# %%
df1.dtypes
# Out:
# _id__$oid         object
# barcode            int64
# category          object
# categoryCode      object
# cpg__$id__$oid    object
# cpg__$ref         object
# name              object
# topBrand          object
# brandCode         object
# dtype: object

# %%
df1 = df1.rename(columns={"_id__$oid": "Brand_id"})

# %%
df1
# Out:
#                       Brand_id       barcode            category  \
# 0     601ac115be37ce2ead437551  511111019862              Baking
# 1     601c5460be37ce2ead43755f  511111519928           Beverages
# 2     601ac142be37ce2ead43755d  511111819905              Baking
# 3     601ac142be37ce2ead43755a  511111519874              Baking
# 4     601ac142be37ce2ead43755e  511111319917      Candy & Sweets
# ...                        ...           ...                 ...
# 1162  5f77274dbe37ce6b592e90c0  511111116752              Baking
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328  Breakfast & Cereal
# 1164  5f494c6e04db711dd8fe87e7  511111416173      Candy & Sweets
# 1165  5a021611e4b00efe02b02a57  511111400608             Grocery
# 1166  6026d757be37ce6369301468  511111019930              Baking
#
#           categoryCode            cpg__$id__$oid cpg__$ref  \
# 0               BAKING  601ac114be37ce2ead437550      Cogs
# 1            BEVERAGES  5332f5fbe4b03c9a25efd0ba      Cogs
# ...

# %%
df1.fillna(0)
df1.replace(np.nan, 0)
# Out:
#                       Brand_id       barcode            category  \
# 0     601ac115be37ce2ead437551  511111019862              Baking
# 1     601c5460be37ce2ead43755f  511111519928           Beverages
# 2     601ac142be37ce2ead43755d  511111819905              Baking
# 3     601ac142be37ce2ead43755a  511111519874              Baking
# 4     601ac142be37ce2ead43755e  511111319917      Candy & Sweets
# ...                        ...           ...                 ...
# 1162  5f77274dbe37ce6b592e90c0  511111116752              Baking
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328  Breakfast & Cereal
# 1164  5f494c6e04db711dd8fe87e7  511111416173      Candy & Sweets
# 1165  5a021611e4b00efe02b02a57  511111400608             Grocery
# 1166  6026d757be37ce6369301468  511111019930              Baking
#
#           categoryCode            cpg__$id__$oid cpg__$ref  \
# 0               BAKING  601ac114be37ce2ead437550      Cogs
# 1            BEVERAGES  5332f5fbe4b03c9a25efd0ba      Cogs
# ...

# %%
df1.to_csv( r'/Users/srinathnarayanan/Downloads/Fetch/Brands.csv', header=True, index=False)

# %%
df2 = pd.read_csv('/Users/srinathnarayanan/Downloads/Fetch Rewards/Receipts.csv', parse_dates=True)

# %%
df2
# Out:
#                       _id.$oid bonusPointsEarned  \
# 0     5ff1e1eb0a720f0523000575               500
# 1     5ff1e1bb0a720f052300056b               150
# 2     5ff1e1f10a720f052300057a                 5
# 3     5ff1e1ee0a7214ada100056f                 5
# 4     5ff1e1d20a7214ada1000561                 5
# ...                        ...               ...
# 1114  603cc0630a720fde100003e6                25
# 1115  603d0b710a720fde1000042a                ""
# 1116  603cf5290a720fde10000413                ""
# 1117  603ce7100a7217c72c000405                25
# 1118  603c4fea0a7217c72c000389                ""
#
#                                 bonusPointsEarnedReason  createDate.$date  \
# 0     Receipt number 2 completed, bonus point schedu...     1609687531000
# 1     Receipt number 5 completed, bonus point schedu...     1609687483000
# 2                            All-receipts receipt bonus     1609687537000
# 3                            All-receipts receipt bonus     1609687534000
# ...

# %%
df2 = df2.rename(columns={"_id.$oid": "Receipt_id"})
df2 = df2.rename(columns={"createDate.$date":"CreateDate"})
df2 = df2.rename(columns={"dateScanned.$date":"dateScanned"})
df2 = df2.rename(columns={"finishedDate.$date":"FinishedDate"})
df2 = df2.rename(columns={"modifyDate.$date":"ModifyDate"})
df2 = df2.rename(columns={"pointsAwardedDate.$date":"pointsAwardDate"})
df2 = df2.rename(columns={"purchaseDate.$date":"purchaseDate"})

# %%
df2.fillna(0)
df2.replace(np.nan, 0)
# Out:
#                     Receipt_id bonusPointsEarned  \
# 0     5ff1e1eb0a720f0523000575               500
# 1     5ff1e1bb0a720f052300056b               150
# 2     5ff1e1f10a720f052300057a                 5
# 3     5ff1e1ee0a7214ada100056f                 5
# 4     5ff1e1d20a7214ada1000561                 5
# ...                        ...               ...
# 1114  603cc0630a720fde100003e6                25
# 1115  603d0b710a720fde1000042a                ""
# 1116  603cf5290a720fde10000413                ""
# 1117  603ce7100a7217c72c000405                25
# 1118  603c4fea0a7217c72c000389                ""
#
#                                 bonusPointsEarnedReason     CreateDate  \
# 0     Receipt number 2 completed, bonus point schedu...  1609687531000
# 1     Receipt number 5 completed, bonus point schedu...  1609687483000
# 2                            All-receipts receipt bonus  1609687537000
# 3                            All-receipts receipt bonus  1609687534000
# ...

# %%
df2['CreateDate']=df2['CreateDate'].apply(lambda d: datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

# %%
df2['dateScanned']=df2['dateScanned'].apply(lambda d: datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

# %%
df2['monthCreate'] = pd.DatetimeIndex(df2['CreateDate']).month
df2['YearCreate'] = pd.DatetimeIndex(df2['CreateDate']).year

df2['monthScanned'] = pd.DatetimeIndex(df2['dateScanned']).month
df2['yearScanned'] = pd.DatetimeIndex(df2['dateScanned']).year
df2.head()
# Out:
#                  Receipt_id bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575               500
# 1  5ff1e1bb0a720f052300056b               150
# 2  5ff1e1f10a720f052300057a                 5
# 3  5ff1e1ee0a7214ada100056f                 5
# 4  5ff1e1d20a7214ada1000561                 5
#
#                              bonusPointsEarnedReason           CreateDate  \
# 0  Receipt number 2 completed, bonus point schedu...  2021-01-03 10:25:31
# 1  Receipt number 5 completed, bonus point schedu...  2021-01-03 10:24:43
# 2                         All-receipts receipt bonus  2021-01-03 10:25:37
# 3                         All-receipts receipt bonus  2021-01-03 10:25:34
# 4                         All-receipts receipt bonus  2021-01-03 10:25:06
#
#            dateScanned   FinishedDate     ModifyDate pointsAwardDate  \
# 0  2021-01-03 10:25:31  1609687531000  1609687536000   1609687531000
# 1  2021-01-03 10:24:43  1609687483000  1609687488000   1609687483000
# ...

# %%
df2.to_csv( r'/Users/srinathnarayanan/Downloads/Fetch/Receipts.csv', header=True, index=False)

# %%
df_Updated_User = df.drop(['role', 'state','lastLoginDate','active','signUpSource'], axis=1)

# %%
df2_Updated_Receipts = df2.drop(['bonusPointsEarnedReason','FinishedDate','ModifyDate','pointsAwardDate','purchaseDate'],axis=1)

# %%
df1_Updated_Brand = df1.drop(['cpg__$ref', 'cpg__$id__$oid','categoryCode','category'], axis=1)

# %%
df_Final_BrandReceUser = pd.concat([df_Updated_User, df1_Updated_Brand,df2_Updated_Receipts],axis=1)

# %%
df_Final_BrandReceUser.to_csv( r'/Users/srinathnarayanan/Downloads/Fetch/df_Final_BrandReceUser.csv', header=True, index=False)
