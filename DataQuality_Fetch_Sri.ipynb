# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read the Users table csv

# %%
df = pd.read_csv('/Users/srinathnarayanan/Downloads/Fetch/users.csv')

# %%
df.head(5)
# Out:
#                     User_id  active       CreateDateUser  lastLoginDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
# 3  5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30   1.609688e+12
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04   1.609688e+12
#
#        role signUpSource state  monthUser  yearUser
# 0  consumer        Email    WI          1      2021
# 1  consumer        Email    WI          1      2021
# 2  consumer        Email    WI          1      2021
# 3  consumer        Email    WI          1      2021
# 4  consumer        Email    WI          1      2021

# %%
df.shape
# Out:
# (495, 9)

# %% [markdown]
# Converty column data lastLoginDate to datetime

# %%
df['lastLoginDate'] = df['lastLoginDate'].astype('datetime64[ns]')

# %%
df.dtypes
# Out:
# User_id                   object
# active                      bool
# CreateDateUser            object
# lastLoginDate     datetime64[ns]
# role                      object
# signUpSource              object
# state                     object
# monthUser                  int64
# yearUser                   int64
# dtype: object

# %%
df
# Out:
#                       User_id  active       CreateDateUser  \
# 0    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 1    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 2    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 3    5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30
# 4    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# ..                        ...     ...                  ...
# 490  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 491  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 492  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 493  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 494  54943462e4b07e684157a532    True  2014-12-19 09:21:22
#
#                     lastLoginDate         role signUpSource state  monthUser  \
# 0   1970-01-01 00:26:49.687537858     consumer        Email    WI          1
# 1   1970-01-01 00:26:49.687537858     consumer        Email    WI          1
# ...

# %%
# Fill NaN value to zero in a complete dataframe using pandas

# %%
df.fillna(0)
# Out:
#                       User_id  active       CreateDateUser  \
# 0    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 1    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 2    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 3    5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30
# 4    5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# ..                        ...     ...                  ...
# 490  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 491  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 492  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 493  54943462e4b07e684157a532    True  2014-12-19 09:21:22
# 494  54943462e4b07e684157a532    True  2014-12-19 09:21:22
#
#                      lastLoginDate         role signUpSource state  monthUser  \
# 0    1970-01-01 00:26:49.687537858     consumer        Email    WI          1
# 1    1970-01-01 00:26:49.687537858     consumer        Email    WI          1
# ...

# %% [markdown]
# Extracting  month and Year of lastLogindate field

# %%
df['monthLastLogin'] = pd.DatetimeIndex(df['lastLoginDate']).month
df['yearLastLogin'] = pd.DatetimeIndex(df['lastLoginDate']).year
df.head()
# Out:
#                     User_id  active       CreateDateUser  \
# 0  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
# 3  5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04
#
#                   lastLoginDate      role signUpSource state  monthUser  \
# 0 1970-01-01 00:26:49.687537858  consumer        Email    WI          1
# 1 1970-01-01 00:26:49.687537858  consumer        Email    WI          1
# 2 1970-01-01 00:26:49.687537858  consumer        Email    WI          1
# 3 1970-01-01 00:26:49.687530597  consumer        Email    WI          1
# 4 1970-01-01 00:26:49.687537858  consumer        Email    WI          1
#
#    yearUser  monthLastLogin  yearLastLogin
# 0      2021             1.0         1970.0
# 1      2021             1.0         1970.0
# 2      2021             1.0         1970.0
# ...

# %%
# Determine count of unique values for each column in the dataframe
df.nunique()
# Out:
# User_id           212
# active              2
# CreateDateUser    212
# lastLoginDate     172
# role                2
# signUpSource        2
# state               8
# monthUser           7
# yearUser            5
# monthLastLogin      1
# yearLastLogin       1
# dtype: int64

# %%
# Checking if any rows are missing any data.
df.isnull().sum()
# Out:
# User_id            0
# active             0
# CreateDateUser     0
# lastLoginDate     62
# role               0
# signUpSource      48
# state             56
# monthUser          0
# yearUser           0
# monthLastLogin    62
# yearLastLogin     62
# dtype: int64

# %%
# Fill NaN values with a mean value
df['lastLoginDate'] = df['lastLoginDate'].fillna(' ')
df['signUpSource'] = df['signUpSource'].fillna('0, inplace=True')
df['monthLastLogin'] = df['monthLastLogin'].fillna('')
df['state'] = df['state'].fillna(' ')
df['yearLastLogin'] = df['yearLastLogin'].fillna(' ')

# %%
# Checking if any rows are missing any data.
df.isnull().sum()
# Out:
# User_id           0
# active            0
# CreateDateUser    0
# lastLoginDate     0
# role              0
# signUpSource      0
# state             0
# monthUser         0
# yearUser          0
# monthLastLogin    0
# yearLastLogin     0
# dtype: int64
